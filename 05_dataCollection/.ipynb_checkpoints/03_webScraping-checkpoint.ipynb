# %%
#3 major libraries for webscraping:
#1. requests 2. BeautifulSoul 3. Selenium
# requests: used to download the webpage i.e HTML
#BeatifulSoup: Pases & extracts data from HTML
#Selenium : Automate a browser to load dynamic JS pages - optional Alternative to (requests+BeautifuulSouup) in case ofdynamic websites

#1. Web scraping by request library      (https://toscrape.com, https://www.scrapethissite.com)

import requests
URL = "https://www.scrapethissite.com/pages/simple/"
response = requests.get(URL)

#print(res.status_code)   # HTTP status (200 = OK)
#print(res.text)          # HTML content of the page as a string
#print(res.content)       # Raw bytes of the response
#print(res.headers)       # Metadata like content-type, server info, etc.

# %%
response
# Out:
# <Response [200]>

# %%
with open("scraped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(response.text)
