# %% [markdown]
# WHOLESALE CUSTOMERS DATASET — COMPLETE GUIDE
# 📂 Dataset Link
#
# 👉 https://archive.ics.uci.edu/ml/datasets/wholesale+customers
#
# 📊 1. DATASET DESCRIPTION (VERY IMPORTANT FOR UNDERSTANDING)
# 📌 Basic Info
# Total Records: 440 customers
# Type: Unsupervised dataset (no labels)
# Domain: Wholesale distribution business
# 📌 Features (Columns)
# 🔹 1. Channel
# Type: Categorical
# Values:
# 1 → Horeca (Hotel/Restaurant/Cafe)
# 2 → Retail
#
# 👉 Meaning:
#
# Type of customer business
# 🔹 2. Region
# Type: Categorical
# Values:
# 1 → Lisbon
# 2 → Oporto
# 3 → Other
#
# 👉 Meaning:
#
# Customer location
# 🔹 3–8. Annual Spending Features (MAIN FEATURES 🔥)
#
# These are the MOST IMPORTANT for clustering:
#
# Fresh → Fresh products (vegetables, fruits)
# Milk → Dairy products
# Grocery → Daily essentials
# Frozen → Frozen food
# Detergents_Paper → Cleaning products
# Delicassen → Luxury food items
#
# 👉 All values are:
#
# Annual spending (in monetary units)
# 🧠 2. DATA UNDERSTANDING (INTUITION)
#
# Each row =
# 👉 “How much a customer spends on different product categories in a year”
#
# So basically:
#
# 👉 You are analyzing BUYING PATTERNS
#
# 🔍 3. REAL-WORLD INTERPRETATION
#
# This dataset helps answer:
#
# Who buys bulk grocery items?
# Who spends more on fresh products?
# Which customers prefer luxury items?
# Which customers are business vs retail type?
# 🎯 4. YOUR FINAL AIM (VERY IMPORTANT 🔥)
# ✅ MAIN OBJECTIVE
#
# Segment customers based on their purchasing behavior across product categories using clustering techniques
