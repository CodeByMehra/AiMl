# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Wholesale customers data.csv")

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df.shape
# Out:
# (440, 8)

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
# No features are irrelevant so we will drop nothing

# %%
df.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
## Creating new features:

df["Total_spendings"] = df["Fresh"] + df["Milk"] + df["Grocery"] + df["Frozen"] + df["Detergents_Paper"] + df["Delicassen"]

# %%
cols = ["Channel", "Region" , "Total_spendings"]

sns.pairplot(df[cols])

# %% [markdown]
# ### Outliers:
#
# 1. high fresh buying at channel 1 (we eill keep the buying limit at 10 lakh to maintain the average)
# 2. uneven correlation of fresh along with grocery

# %%
df.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen', 'Total_spendings'],
#       dtype='object')

# %%
cols = ["Channel", "Region", "Total_spendings"]

df_cleaned = df[cols]

# %%
corr = df_cleaned.corr(numeric_only= True)
corr
# Out:
#                   Channel    Region  Total_spendings
# Channel          1.000000  0.062028         0.351177
# Region           0.062028  1.000000         0.039039
# Total_spendings  0.351177  0.039039         1.000000

# %%
# Correlation heatmap

plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

X = df_cleaned
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# %%
#plot

plt.scatter(X_pca[:,0], X_pca[:,1])

# %%
pca = PCA(n_components=3)

X_pca = pca.fit_transform(X_scaled)

# plot (3D)
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2])

ax.set_xlabel("PCA1")
ax.set_ylabel("PCA2")
ax.set_zlabel("PCA3")
ax.set_title("3d projection")
# Out:
# Text(0.5, 0.92, '3d projection')

# %%
# finding the optimal k:


from sklearn.cluster import KMeans
from kneed import KneeLocator

wcss = []
for k in range (1,11):
    kmeans = KMeans (n_clusters= k, random_state=42)
    kmeans.fit_predict(X_pca)
    wcss.append(kmeans.inertia_)

# %%
knee = KneeLocator(range(1,11) , wcss, curve= "convex", direction= "decreasing")

optimal_k = knee.elbow

# %%
optimal_k
# Out:
# np.int64(4)

# %%
#plot

plt.plot(range(1,11), wcss, marker='o')
plt.xlabel("k")
plt.ylabel("wcss")
# Out:
# Text(0, 0.5, 'wcss')

# %%
# Silhoutte score:

from sklearn.metrics import silhouette_score

scores = []

for k in range(2,11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    scores.append(score)

#plot
plt.plot(range(2,11), scores, marker='o')
plt.xlabel("k")
plt.ylabel("scores")
# Out:
# Text(0, 0.5, 'scores')

# %%
#Combined plot

k_range = range(2,11)

fig, ax1 = plt.subplots(figsize=(10,8))

ax1.plot(k_range, wcss[:len(k_range)], marker= "o",color = "blue")
ax1.set_xlabel("k")
ax1.set_ylabel("wcss")

ax2 = ax1.twinx()
ax2.plot(k_range, scores[:len(k_range)], marker = "x" , color= "red", linestyle="--")
ax2.set_ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %%
# Clustering :


kmeans = KMeans(n_clusters=4, random_state=42)
labels_kmeans = kmeans.fit_predict(X_pca)

# #plot 
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels_kmeans)

# %%
# Agglomerative clustering

from sklearn.cluster import AgglomerativeClustering

# %%
agg_clf = AgglomerativeClustering(n_clusters=4 , linkage="ward")
labels_agg = agg_clf.fit_predict(X_pca)

#plot 
fig = plt.figure(figsize=(8, 6))

ax = fig.add_subplot(111, projection="3d")

ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=labels_agg)
