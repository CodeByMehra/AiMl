# %% [markdown]
# in this clustering , we dont specify the number of cluster
#
# there are no entroids
#
# Tw2o types:
# 1 Aglomertive (Bottom up)
#
# 2 Divisive (top down)

# %% [markdown]
# ### 1. Aglomerative:
#
# it starts by defining each point as an individual cluser, andstyart by combining the nearest
#
# ### 2. Divisive:
#
# all data points are considered as a single cluster and then the sub clusters are made based on the distance

# %% [markdown]
# ## Dendrogram:
#
# dendrogram is a tree like diagram that generated in aglomerative clustering
#
# a longest verical line is drawn in the dendrogram with no horizontal crossing to determine the number of clusters

# %% [markdown]
# # Difference bw kmeans and hierarchical clustering:
#
# 1. number of clusters needed to be defined in k means, in hierarchical it can be decided later using dendrogram
#
# 2. large datasets in kmeans
