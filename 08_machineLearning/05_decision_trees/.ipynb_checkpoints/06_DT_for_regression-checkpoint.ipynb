# %% [markdown]
# In the case of regression, we use variance instead of Gini impurity
# variance reduction is used for feature selection instead of information gain
# Variance Reduction = Var. of parent - weighted variance of chuldren nodes
