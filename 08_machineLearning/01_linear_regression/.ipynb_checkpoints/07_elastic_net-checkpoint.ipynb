# %%
#it is a combination of lasso regression and ridge regression
#following docmentation can be taken into consideration for brief overview:
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html
