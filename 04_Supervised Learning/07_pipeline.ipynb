# %% [markdown]
# ### pipeline allow us to sequentially apply a list of tranformers to process the data and, if desired, conclude the sequence with a final predictor for predictive modeling
#
# ### in knn, there is problem occuring of data leakage becase the validation set also getting scaled
#
# ### by pipeline, we achieve functionality in cross validation that only training sets will be svaled excluding the validation set
