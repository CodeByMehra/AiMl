# %% [markdown]
# # Sarsa implementation for cliff walking problem

# %%
# !pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/953.9 kB ? eta -:--:--
#    ---------------------------------------- 953.9/953.9 kB 3.3 MB/s  0:00:00
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, gymnasium
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    ---------------------------------------- 2/2 [gymnasium]
#
# Successfully installed farama-notifications-0.0.6 gymnasium-1.3.0

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# Requirement already satisfied: gymnasium[toy-text] in c:\users\dell\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium[toy-text]) (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium[toy-text]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium[toy-text]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\dell\anaconda3\lib\site-packages (from gymnasium[toy-text]) (0.0.6)
# Collecting pygame-ce>=2.1.3 (from gymnasium[toy-text])
#   Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Downloading pygame_ce-2.5.7-cp313-cp313-win_amd64.whl (10.4 MB)
#    ---------------------------------------- 0.0/10.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.4 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/10.4 MB 5.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.4 MB 5.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/10.4 MB 5.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------ --------------- 6.3/10.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.3/10.4 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 8.7/10.4 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.4/10.4 MB 5.7 MB/s  0:00:01
# Installing collected packages: pygame-ce
# Successfully installed pygame-ce-2.5.7

# %%
import gymnasium as gym
import numpy as np
import random

# %% [markdown]
# ### some methods of env object
# 1. create - make()
# 2. show - render()
# 3. reset - reset()
# 4. close - close()
# 5. action - step()

# %%
# Sample env:

env = gym.make("CliffWalking-v1")

# %%
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v1>>>>

# %%
print(env.observation_space.n) # states
print(env.action_space.n) # actions

starting_state, _ = env.reset() # 36 = 3 * 12 + 0
print(starting_state) # 36
# Out:
# 48
# 4
# 36

# %% [markdown]
# # SARSA

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 500

# %%
# Q-table => store Q-values

Q = np.zeros((48, 4)) # A grid of 48X4 initialized with zeros

# %%
# Policy - epsilon-greedy : state -> action

def epsilon_greedy(state):
    if random.random() < epsilon:
        return env.action_space.sample() # random action => EXPLORE
    else:
        return np.argmax(Q[state])  # exploit [return the most optimal value]

# %%
for episode in range(episodes):  # Train the agent on multiple episodes
    render = (episode % 50 == 0)    

    if render:
        env = gym.make("CliffWalking-v1", render_mode="human")
        print(f"rendering env for episode={episode+1}/500")
    else:
        env = gym.make("CliffWalking-v1")

    done = False # when the episode has ended
    state, _ = env.reset()
    action = epsilon_greedy(state)

    total_reward = 0
    episode_len = 0

    while not done:
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        # SARSA update
        Q[state, action] += alpha * (reward + gamma*(Q[next_state, next_action] - Q[state, action]))

        state = next_state
        action = next_action

        total_reward += reward
        episode_len += 1

    print(f"episode={episode+1}/500: total reward = {total_reward} & ep length = {episode_len}")
    env.close()
# Out:
# rendering env for episode=1/500
