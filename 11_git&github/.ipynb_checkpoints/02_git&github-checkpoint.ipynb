# %% [markdown]
# # Git and Github
#
# ### Git :
# it is free and open source version control system, a tool that helps to track changes in code
#
# ### GitHub:
# it is a website where we host repositories online, it is based in git
