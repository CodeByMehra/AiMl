# %% [markdown]
# # Git and Github
#
# ### Git :
# it is free and open source version control system, a tool that helps to track changes in code
#
# ### GitHub:
# it is a website where we host repositories online, it is based in git

# %% [markdown]
# ## Basic Git Commands:
#
# ### 1. Clone -
# cloning a repo in our local machine
#
# ### 2. status-
# displays the state of the code
#
# ### 3. add -
# adds new or changed files in your working directory to the Git staging area.        git add <- filename ->
#
# ### 4. Commit -
# it is the rcord of change.      git commit -m "some message"
#
# ### 5. push -
# upload local repo content to remove repo                 git push origin main
