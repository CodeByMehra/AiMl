# %% [markdown]
# # RNN for sentiment analysis for IMDB data

# %%
import pandas as pd

# %%
df = pd.read_csv("/IMDB Dataset.csv")

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (49582, 2)

# %% [markdown]
# # Pre Processing

# %% [markdown]
# ### 1. Converting to Lowercase:

# %%
df["review"]= df["review"].str.lower()  # The strings that are available in the DF will be converted to Lowercase

# %% [markdown]
# ### 2. Removing the URLs

# %%
# To perform this action, we use oprn source library of pythom named re (regular expression)

import re

def remove_urls(text):
    text = re.sub(r"http\S+", "" , text)  # (pattern, replacement, string)
    return text
             # \S -> Non whitespace characters after the text (capital S)
             # \s -> whitespace character

df["review"] = df["review"].apply(remove_urls)

# %% [markdown]
# ### 3. Remove punctuations:

# %%
# We will consider the values as punctuations that does not comes under the range A-Z a-z 0-9 and \s (space)
def remove_punctuations(text):
    text = re.sub(r"^[A-Za-z0-9\s]", "" , text) # ^ means include
    return text

df["review"] = df["review"].apply(remove_punctuations)

# %% [markdown]
# ### 4, Removing HTML tags

# %%
# Some symbols in RegEx:
# . -> any character
# * -> 0 or more character

def remove_html(text):
    text = re.sub(r"<.*?>", "" , text)
    return text

df["review"] = df["review"].apply(remove_html)

# %% [markdown]
# ### 5. Remove Stopwords

# %%
import nltk

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
def remove_stopwords(text):
    tokens = word_tokenize(text)
    stop_words = stopwords.words("english")

    for word in tokens:
        if word in stop_words:
            text = text.replace(word, "")

    return text

df["review"] = df["review"].apply(remove_stopwords)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  ne    revewers  nted   wtchg  1 oz epode 'll  ...  positive
# 1   wderful ltle producti.  filming technique   u...  positive
# 2   thought    wderful wy  spend tme   o hot summ...  positive
# 3  sclly 's  fmly   lttle boy (jke) thks 's  zomb...  negative
# 4  etter mttei's "love   time  mey"   vully stunn...  positive

# %% [markdown]
# ### 6. Stemming

# %%
# Converting words to their base form using very famous algorithm - potter stemming

from nltk.stem import PorterStemmer

def stemming(text):
    stemmer = PorterStemmer()
    stemmed_words = []

    tokens = word_tokenize(text)

    for word in tokens:
        stemmed_word = stemmer.stem(word)
        stemmed_words.append(stemmed_word)

    return " ".join(stemmed_words)


df["review"] = df["review"].apply(stemming)

# %% [markdown]
# ### 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["sentiment"] = le.fit_transform(df["sentiment"])

# %%
y= df["sentiment"]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: sentiment, Length: 49582, dtype: int64

# %% [markdown]
# ### 8. Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

TfidfVectorizer(max_features=2500)
