# %% [markdown]
# After understanfing the problem, the first step is to understand the data
#
# This step include:
#
# Shape of dataset
# Column names
# Data types
# First few rows
# Target distribution
#
# folloeings can be taken iun
