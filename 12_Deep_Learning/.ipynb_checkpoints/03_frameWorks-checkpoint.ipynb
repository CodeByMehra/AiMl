# %% [markdown]
# - in deep learning , we use following frameworks
#
# - ## 1. PyTorch :
#
#    - it is created by facebook
#
# - ## 2. TensorFlow :
#
#    - Created by Google
#    - keras : it is a high level API
#
#
# ## Alternative (Google Colab):
#
# it is a sloud based jupyter notebook environments
