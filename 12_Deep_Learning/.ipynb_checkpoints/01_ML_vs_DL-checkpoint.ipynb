# %% [markdown]
# ## Difference between ML and DL
#
# - ML deals with structured data (XL, CSV) and Dl can also deal with unstructured data (Text, Images , Phots and videos)
# - ML use data to perfrom simple tasks, But big DL use Big data for complex tasks
# - ML algos are more interpretable, DL algoes are less interpretable(Blackbox)
