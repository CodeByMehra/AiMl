# %% [markdown]
# ## Loss function:
#
#
# ### For regression:
# 1. MSE
# 2. MAE
# 3. Huberloss
#
# ### For Classification:
#
# 1. cross entropy:
#    1. Binary cross entropy
#    2. categorical cross entropy
# 2.
