# %%
import seaborn as sns
import matplotlib.pyplot as sns

# %%
sns.get_dataset_names() #AVAILABLE DATASETS
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.get_dataset_names() #AVAILABLE DATASETS
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'get_dataset_names'
